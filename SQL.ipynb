# %% [markdown]
# <a href="https://colab.research.google.com/github/WevertoonDev/Estudando_SQL/blob/main/SQL.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-15e519fe-4ec6-43d4-9dfa-aa6fc1f3fdc7" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-15e519fe-4ec6-43d4-9dfa-aa6fc1f3fdc7">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd

df = pd.read_csv('SQLite (2).csv')
df.head()
# Out:
#    id data_do_pedido       status  total_do_pedido  cliente data_de_envio_es
# 0   1     2023-08-01     Pendente           150.00        5       2023-08-10
# 1   2     2023-08-02  Processando           280.50        8       2023-08-15
# 2   3     2023-08-03      Enviado           450.75       12       2023-08-12
# 3   4     2023-08-04     Entregue            90.25        2       2023-08-05
# 4   5     2023-08-05  Processando           520.00       17       2023-08-20
